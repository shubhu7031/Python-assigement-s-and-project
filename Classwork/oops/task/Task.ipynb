# %% [markdown]
# # Task
# ## 1. Print table of all even numbers whether range starts from 2 to n...
# ## 2. Output: 2 x 1 = 2

# %%
num=int(input('enter any num:- '))
for i in range (2,num+1):
  if i%2==0:
    for a in range(1,11):
      print(i,'X',a,'=',i*a)
    a+=1
# Out:
# enter any num:- 1

# %%
class Display:
    def __init__(self, val):
        self.val = val
    def increase(self):
        self.val += 1
    def show(self):
        print(self.val)

c=Display(99)

# while c<=150:
#   c.increase()
c.show()
# Out:
# 99
# <__main__.Display object at 0x7fe4d59ca490>
# 99

# %% [markdown]
# <pre>
# =============== RESTART: C:/Users/DELL/Desktop/pizzasystem.py ===============
#
# 		Welcome to Amazing Pizza and Pasta Pizzeria
#
#  press 1 : order menu
#
#  press 2 : Exit
#
# Enter your choice :1
#
#  1 large pizza = 10.99 AUD
#
#  2 large Pizzas = 20.99 AUD
#
#  3 Large Pizzas = 29.99 AUD
#
#  ***Buy 4 or more pizza and get 1.5lt of soft drink free***
#
#
# 1 large pasta = 9.5 AUD
#
# 2 large pastas = 17.00 AUD
#
# 3 large pastas = 27.50 AUD
#
# ***Buy 4 or more pastas and get 2 bruschetta free.***
#
# ***Buy 4 or more pizzas and pastas and get 2 chocco brownies ice cream free.
#
# --------------------------------
#
# Enter your name : Anjali
#
#  Welcome,  Anjali
# Enter number or pizza order you want :4
#
# 	 your pizza order amount is : 43.96
#
# 		 *** Congratulations !! 1.5lt softdrink free ***
# Enter number or pasta order you want :6
#
# 	 your pasta order amount is : 57.0
#
# 		 *** Congratulations !! get 2 bruschetta free ***
#
# 		 *** Congratulations !! get 2 chocco brownies ice cream free ***
#
#  your total order is :  100.96000000000001
#
# -----> your Net order amount of the day is :  100.96000000000001
#
#  want to enter order from another customer (Y/N) : Y
# Enter your name : enji
#
#  Welcome,  enji
# Enter number or pizza order you want :4
#
# 	 your pizza order amount is : 43.96
#
# 		 *** Congratulations !! 1.5lt softdrink free ***
# Enter number or pasta order you want :3
#
# 	 your pasta order amount is : 27.0
#
#  your total order is :  70.96000000000001
#
# -----> your Net order amount of the day is :  171.92000000000002
#
#  want to enter order from another customer (Y/N) : N
#
# ----------- Pizza and pasta Bill --------------
#
#
#  payment received from pizza :  87.92
#
#  payment received from pasta :  84.0
#
#  payment received today :  171.92000000000002
#
#  Number of pizza and pasta sold in one shift :  17
#
#  Number of 1.5lt soft drink bottles given :  2
#
#  Number of bruschetta given to customer : 2
#
#  Number of chocco brownies ice cream given to customer : 2
#
#  Bye Bye !!!
# >>>
# </pre>

# %%
class calc:
  def sum_num(x,y):
    return x+y
  
  def mul_num(x,y):
    return x*y
  
  def sub_num(x,y):
    return x-y
  
  def div_num(x,y):
    return x/y

ca=calc

ca.div_num(28,8)
# Out:
# 3.5

# %%
# Illustration of creating a class
# in Python with input from the user
class Student:
	'A student class'
	stuCount = 0

	# initialization or constructor method of
	def __init__(self):
		
		# class Student
		self.name = input('enter student name:')
		self.rollno = input('enter student rollno:')
		Student.stuCount += 1

	# displayStudent method of class Student
	def displayStudent(self):
		print("\nName:", self.name, "Rollno:", self.rollno)


stu1 = Student()
stu2 = Student()
stu3 = Student()
stu1.displayStudent()
stu2.displayStudent()
stu3.displayStudent()
print('\ntotal no. of students:', Student.stuCount)
# Out:
# enter student name:rakesh\
# enter student rollno:7004
# enter student name:seuasddf
# enter student rollno:5465
# enter student name:adsdaerf
# enter student rollno:3453
#
# Name: rakesh\ Rollno: 7004
#
# Name: seuasddf Rollno: 5465
#
# Name: adsdaerf Rollno: 3453
#
# total no. of students: 3

# %%
#Pizzeria

#creating a class Pizzeria
class Pizzeria:
  #total amount counter
  total_amount=0

  #option function for menu or exit
  def option():
    print("\nPress 1 for Order Menu\nPress 2 for Exit")
    opt=int(input("\nChoose Option from above:- "))
    if opt==1:
      #if user opted 1 menu is Showing
      Pizzeria.menu()
      #Calling billing function after showing menu
      Pizzeria.c_bill()

    elif opt==2:
      pass
    else:
      print("\ninvalid input...!")
      Pizzeria.option()

  def menu():
    food_menu="""
1 large pizza = 10.99 AUD 

2 large Pizzas = 20.99 AUD 

3 Large Pizzas = 29.99 AUD

***Buy 4 or more pizza and get 1.5lt of soft drink free***


1 large pasta = 9.5 AUD 

2 large pastas = 17.00 AUD 

3 large pastas = 27.50 AUD

***Buy 4 or more pastas and get 2 bruschetta free.***

***Buy 4 or more pizzas and pastas and get 2 chocco brownies ice cream free.
-----------------------------------------------------
"""
    print(food_menu)

  #this is billing function
  def c_bill():
    #individual customer amount counter is c_amount
    c_amount=0
    #Asking user for customer's name
    c_name=input("\nEnter Your Name:- ")
    print("Welcome, ",c_name)

    #Asking to user for buying qty of pizza
    qty_pizza=int(input("\nEnter number or pizza order you want : "))
    if qty_pizza==1:
      print("\tYour pizza order amount is : ",10.99,"AUD\n")
    elif qty_pizza==2:
      print("\tYour pizza order amount is : ",20.99,"AUD\n")
    elif qty_pizza==3:
      print("\tYour pizza order amount is : ",29.99,"AUD\n")
    elif qty_pizza>=4:
      pizza_amount=10.99*qty_pizza
      print("\t\t*** Congratulations !! 1.5lt softdrink free ***")
      print("\tYour pizza order amount is : ",pizza_amount,"AUD\n")
    else:
      print("\nEnter invalid input...!")
    c_amount+=pizza_amount
      
    #Asking to user for buying qty of pasta
    qty_pasta=int(input("\nEnter number or pasta order you want : "))
    if qty_pasta==1:
      print("\tYour pizza order amount is : ",9.50,"AUD\n")
    elif qty_pasta==2:
      print("\tYour pizza order amount is : ",17.00,"AUD\n")
    elif qty_pasta==3:
      print("\tYour pizza order amount is : ",27.50,"AUD\n")
    elif qty_pasta>=4:
      pasta_amount=9.5*qty_pasta
      print("\t\t*** Congratulations !! get 2 bruschetta free ***\n")
      print("\t\t*** Congratulations !! get 2 chocco brownies ice cream free ***\n")
      print("\tYour pasta order amount is : ",pasta_amount,"AUD\n")
    c_amount+=pasta_amount
    print("your billing amount is, ",c_amount)
      

Pizzeria.option()
# Out:
# Press 1 for Order Menu
# Press 2 for Exit
#
# 1 large pizza = 10.99 AUD
#
# 2 large Pizzas = 20.99 AUD
#
# 3 Large Pizzas = 29.99 AUD
#
# ***Buy 4 or more pizza and get 1.5lt of soft drink free***
#
#
# 1 large pasta = 9.5 AUD
#
# 2 large pastas = 17.00 AUD
#
# 3 large pastas = 27.50 AUD
#
# ***Buy 4 or more pastas and get 2 bruschetta free.***
#
# ***Buy 4 or more pizzas and pastas and get 2 chocco brownies ice cream free.
# -----------------------------------------------------
#
# Welcome,  shubham
# 		*** Congratulations !! 1.5lt softdrink free ***
# 	Your pizza order amount is :  54.95 AUD
#
# 		*** Congratulations !! get 2 bruschetta free ***
#
# 		*** Congratulations !! get 2 chocco brownies ice cream free ***
#
# 	Your pasta order amount is :  66.5 AUD
#
# your billing amount is,  121.45
